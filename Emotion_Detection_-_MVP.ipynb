# %% [markdown]
# # Emotion Detection

# %% [markdown]
# ### Minimum Viable Product

# %% [markdown]
# ##### Goal
# The aim of this project is to utilize deep learning models to detect and predict emotions from faces.
# The deep learning model learns these emotions based on pictures.

# %% [markdown]
# ##### Project Progress
# After downloading the dataset from **[Kaggle](https://www.kaggle.com/ptfrwrd/affectnet)**, we took a sample of **50,000** pictures and their labels (emotions). From the figure below, we can see that the dataset is imbalanced with the neutral and happy emotions making up almost **73%** of the dataset.

# %% [markdown]
# ![class_imbalance-2.png](attachment:class_imbalance-2.png)

# %% [markdown]
# After that, we used Logistic Regression as a baseline model. The training score was **65%** and the validation score was **56%** which means the model was slightly overfitting. The figure below describes the predictions made by the model.

# %% [markdown]
# ![Baseline%20Logistic%20Regression%20confusion%20matrices.png](attachment:Baseline%20Logistic%20Regression%20confusion%20matrices.png)
